# %%
import pandas as pd
dfs = pd.read_excel('CompiledDatav4_fixeddata.xlsx', sheet_name="PassengerKilometresTravelled")
dfs.head()
# Out:
#   LOCATION CountryName   INDICATOR SUBJECT  MEASURE CountryYear  TIME  \
# 0      AUS   Australia  PASSTRANSP    ROAD  MLN_PKM     AUS1970  1970
# 1      AUS   Australia  PASSTRANSP    ROAD  MLN_PKM     AUS1971  1971
# 2      AUS   Australia  PASSTRANSP    ROAD  MLN_PKM     AUS1972  1972
# 3      AUS   Australia  PASSTRANSP    ROAD  MLN_PKM     AUS1973  1973
# 4      AUS   Australia  PASSTRANSP    ROAD  MLN_PKM     AUS1974  1974
#
#         PKT          GDP  RoadNetwork       ...              A34       A39  \
# 0  104210.0  4.12611e+10          NaN       ...         0.061849  0.057353
# 1  109610.0  4.51383e+10          NaN       ...         0.062906  0.057573
# 2  116155.0  5.19544e+10          NaN       ...         0.064079  0.057923
# 3  120295.0   6.3722e+10          NaN       ...         0.065338  0.058373
# 4  127763.0  8.88091e+10          NaN       ...         0.066634  0.058873
#
#         A44       A49       A54       A59       A64       A69       A70  \
# ...
