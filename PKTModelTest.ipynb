# %% [markdown]
# ## PKT data panel regression model test ##

# %% [markdown]
# The first task here is to see what data is available. Lets pull the data into Python to see how it is.

# %%
import pandas as pd
from pandas import Series,DataFrame

# numpy, matplotlib, seaborn
import numpy as np
from numpy import array
import math
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# machine learning
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVC, LinearSVC
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
import sklearn
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from datetime import date
from sklearn import datasets
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score




transport_df = pd.read_csv("ds_challenge_v2_data.csv")

# preview the data
#uber_df.head()
#uber_df.info()
#print("----------------------------")

# dealing with third column
# replacing the signup NAN with otheros

####################################################DATA VISUALIZATION#############################################

#############################################################################################
k= uber_df['signup_os'].replace(np.NaN, 'otheros', regex=True)
#k= uber_df['signup_os'].replace(~np.isNaN, 'otheros', regex=True)
uber_df['signup_os'] = k

# reduce the number of columns to only the ones with data that I want to deal with
#NOTE TO SELF: HAVENT Vectorized the vehicle make. can do that, very cumbersome. ::::::::::Can use EXCEL:::::::::::::
uber_df = uber_df.drop(['id','signup_date', 'bgc_date','vehicle_added_date','carmakerhighend','Unnamed: 12','vehicle_model','first_completed_date'], axis=1)

#removing NAN's from columns of vehicle_make and vehicle_year
df2 = uber_df.dropna(subset=['vehicle_year'])


#categorization
p = df2['last_column'].replace(np.NaN, '0', regex=True)

df2['last_column'] = p

l = df2['vehicle_year']

l2 = l.astype(np.int64)

#b = df2['carmakerhighend'].replace(np.NaN, '0', regex=True)
#df2['carmakerhighend'] = b
       
#converting vehicle year to number based on arbitary year value:

#newlist = []
#for i in l2:
 #   if i <= 2012:
  #      i = 'Low'
   #     newlist.append(i)
    #elif i > 2012:
     #   i = 'High'
      #  newlist.append(i)
        

#df2['vehicle_year']=newlist



dummy = pd.get_dummies(df2['city_name'])
dummy2 = pd.get_dummies(df2['signup_os'])
dummy3 = pd.get_dummies(df2['signup_channel'])
dummy4 = pd.get_dummies(df2['vehicle_year'])
dummy5 = pd.get_dummies(df2['vehicle_make'])
#dummy6 = pd.get_dummies(df2['vehicle_year'])
df = pd.concat([df2,dummy], axis=1)
df = pd.concat([df,dummy2], axis=1)
df = pd.concat([df,dummy3], axis=1)
df = pd.concat([df,dummy4], axis=1)
df = pd.concat([df,dummy5],axis =1)
#df = pd.concat([df,dummy6],axis =1)
df = df.drop(['city_name','signup_os','signup_channel','last_column','vehicle_year', 'vehicle_make'],axis=1)

df.head()
print(df)


X_train, X_test, y_train, y_test = train_test_split(df, p, test_size=0.1)
print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
y_train=y_train.astype('int')
y_test=y_test.astype('int')
# Implementing Logistic Regression model



#df.head()
feat_labels =list(df)
#print(feat_labels)
#print(p)

# %%
import pandas as pd
from pandas import Series,DataFrame

# numpy, matplotlib, seaborn
import numpy as np
from numpy import array
import math
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# machine learning
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVC, LinearSVC
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
import sklearn
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from datetime import date
from sklearn import datasets
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score




#transport_df = pd.read_csv("ds_challenge_v2_data.csv")

# %%
transport_df = pd.read_csv("DataForPython.csv")

# %%
transport_df.head()
# Out:
#   LOCATION CountryName   INDICATOR SUBJECT  MEASURE CountryYear  TIME  \
# 0      AUS   Australia  PASSTRANSP    ROAD  MLN_PKM     AUS1970  1970
# 1      AUS   Australia  PASSTRANSP    ROAD  MLN_PKM     AUS1971  1971
# 2      AUS   Australia  PASSTRANSP    ROAD  MLN_PKM     AUS1972  1972
# 3      AUS   Australia  PASSTRANSP    ROAD  MLN_PKM     AUS1973  1973
# 4      AUS   Australia  PASSTRANSP    ROAD  MLN_PKM     AUS1974  1974
#
#    Unnamed: 7       PKT Flag Codes       ...              A39       A44  \
# 0         NaN  104210.0        NaN       ...         0.057353  0.063364
# 1         NaN  109610.0        NaN       ...         0.057573  0.061237
# 2         NaN  116155.0        NaN       ...         0.057923  0.059331
# 3         NaN  120295.0        NaN       ...         0.058373  0.057593
# 4         NaN  127763.0        NaN       ...         0.058873  0.055963
#
#         A49       A54       A59       A64       A69       A70  CountryArea  \
# ...

# %%
transport_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1837 entries, 0 to 1836
# Data columns (total 33 columns):
# LOCATION           1837 non-null object
# CountryName        1837 non-null object
# INDICATOR          1837 non-null object
# SUBJECT            1837 non-null object
# MEASURE            1837 non-null object
# CountryYear        1837 non-null object
# TIME               1837 non-null int64
# Unnamed: 7         0 non-null float64
# PKT                1791 non-null float64
# Flag Codes         215 non-null object
# GDP                1473 non-null float64
# RoadNetwork        779 non-null float64
# Area               0 non-null float64
# Population         1837 non-null object
# Urbanization       1583 non-null float64
# HDI                979 non-null float64
# A4                 837 non-null float64
# A9                 837 non-null float64
# A14                837 non-null float64
# A19                837 non-null float64
# A24                837 non-null float64
# ...

# %%
list(transport_df)
# Out:
# ['LOCATION',
#  'CountryName',
#  'INDICATOR',
#  'SUBJECT',
#  'MEASURE',
#  'CountryYear',
#  'TIME',
#  'Unnamed: 7',
#  'PKT',
#  'Flag Codes',
#  'GDP',
#  'RoadNetwork',
#  'Area ',
#  'Population',
#  'Urbanization',
#  'HDI',
#  'A4',
#  'A9',
#  'A14',
#  'A19',
#  'A24',
#  'A29',
#  'A34',
#  'A39',
#  'A44',
#  'A49',
#  'A54',
#  'A59',
#  'A64',
#  'A69',
#  'A70',
#  'CountryArea',
#  'OilPricesGlobal']
